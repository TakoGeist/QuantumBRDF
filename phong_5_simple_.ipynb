# %%
import pennylane as qml
import pennylane.numpy as np
from model import Model

# %%
name = 'phong_5_simple_stupid'
def func(n, phi):
    return np.cos(phi) ** n
consts = {'ks': 0.5}
scalars = {'n': {'range':(5,5), 'type': np.uint32}}
angles = {'phi': {'range':(0, np.pi / 2)}}

# %%
model = Model(name)
model.set_function(func)
# model.set_consts(consts)
model.set_scalars(scalars)
model.set_angles(angles)

model.set_sample_size(70)

try:
	model.read_samples('samples/' + model.name + '.bin')
except FileNotFoundError:
	model.generate_samples()
	model.read_samples('samples/' + model.name + '.bin')

model.separate()

# %%
n_qubits = 2
layers = 7

model.push_extra('n_qubits', n_qubits)
model.push_extra('layers', layers)
model.generate_device(n_qubits)


def embedding(data, n_qubits):
	for i in range(n_qubits):
		if i < len(model.scalars):
			value = data[i]
			name = model.header[i + len(model.consts)]
			(min, max) = model.scalars.get(name).get('range')
			if min == max:
				value = value / max * np.pi / 2
			else:
				value = (value - min) / (max - min) * np.pi
			qml.RY(value, wires=i)
		else:
			qml.RY(data[i], wires=i)

	qml.Barrier()


def rot_ent(params, n_qubits):
	if len(params) < n_qubits * 3:
		raise ValueError('Not enough params')

	for i in range(n_qubits):
		qml.RX(params[3 * i], wires=i)
		qml.RY(params[3 * i + 1], wires=i)
		qml.RX(params[3 * i + 2], wires=i)

	for i in range(n_qubits):
		qml.CNOT(wires=[i, (i + 1) % n_qubits])

	qml.Barrier()


model.push_extra('embedding', embedding)
model.push_extra('rot_ent', rot_ent)


def _circuit(data, params):
	layers = model.extra.get('layers')
	n_qubits = model.extra.get('n_qubits')

	model.extra.get('rot_ent')(params, n_qubits)
	for i in range(layers):
		temp_params = params[i * n_qubits * 3 : (i + 1) * n_qubits * 3]
		model.extra.get('embedding')(data, n_qubits)
		model.extra.get('rot_ent')(temp_params, n_qubits)

	return qml.expval(qml.PauliZ(0) @ qml.PauliZ(1))


def _model(circ, input, params):
	return (circ(input, params) ) 


model.set_model(_model)
model.set_circuit(_circuit)
model.generate_params((n_qubits * 3 * (layers + 1),))

qml.draw_mpl(model.circuit, style='sketch')(model.train_in, model.params)
# Out:
# (<Figure size 6500x300 with 1 Axes>, <Axes: >)

# %%
model.set_max_steps(500)
model.set_objective(1E-6)
model.optimization(objective=True, callback= 'graph')
# Out:
# Loss: 0.00020393801896213736
# Step 55
# Estimated time remaining: 00:10:36:900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 model.set_max_steps(500)
#       2 model.set_objective(1E-6)
# ----> 3 model.optimization(objective=True, callback= 'graph')
#
# File ~/thesis/code/model.py:382, in Model.optimization(self, objective, callback)
#     374 self.checkpoints.append(
#     375 	{
#     376 		'loss': copy.copy(loss),
#    (...)    379 	}
#     380 )
#     381 while self.objective < loss and self.max_steps != i:
# --> 382 	params, loss = self.update_step(
#     383 		self.train_in, self.train_out, i, callback, last_time
#     384 	)
#     386 	last_time = time.time_ns()
#     388 	if loss < minloss:
#
# File ~/thesis/code/model.py:336, in Model.update_step(self, input, output, step, callback, last_time)
#     335 def update_step(self, input, output, step, callback, last_time):
# --> 336 	params, loss = self.optimizer.step_and_cost(
#     337 		lambda p: self.loss(p, input, output), self.params
#     338 	)
#     340 	self.losses.append(loss)
#     342 	if callback == 'text':
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/optimize/gradient_descent.py:64, in GradientDescentOptimizer.step_and_cost(self, objective_fn, grad_fn, *args, **kwargs)
#      44 def step_and_cost(self, objective_fn, *args, grad_fn=None, **kwargs):
#      45     """Update trainable arguments with one step of the optimizer and return the corresponding
#      46     objective function value prior to the step.
#      47
#    (...)     61         If single arg is provided, list [array] is replaced by array.
#      62     """
# ---> 64     g, forward = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      65     new_args = self.apply_grad(g, args)
#      67     if forward is None:
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/optimize/gradient_descent.py:122, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#     104 r"""Compute the gradient of the objective function at the given point and return it along with
#     105 the objective function forward pass (if available).
#     106
#    (...)    119     will not be evaluated and instead ``None`` will be returned.
#     120 """
#     121 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 122 grad = g(*args, **kwargs)
#     123 forward = getattr(g, "forward", None)
#     125 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/_grad.py:318, in grad.__call__(self, *args, **kwargs)
#     315     self._forward = self._fun(*args, **kwargs)
#     316     return ()
# --> 318 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     319 self._forward = ans
#     321 return grad_value
#
# File ~/thesis/.venv/lib/python3.12/site-packages/autograd/wrap_util.py:23, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      21 else:
#      22     x = tuple(args[i] for i in argnum)
# ---> 23 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/_grad.py:336, in grad._grad_with_forward(fun, x)
#     330 @staticmethod
#     331 @unary_to_nary
#     332 def _grad_with_forward(fun, x):
#     333     """This function is a replica of ``autograd.grad``, with the only
#     334     difference being that it returns both the gradient *and* the forward pass
#     335     value."""
# --> 336     vjp, ans = _make_vjp(fun, x)  # pylint: disable=redefined-outer-name
#     338     if vspace(ans).size != 1:
#     339         raise TypeError(
#     340             "Grad only applies to real scalar-output functions. "
#     341             "Try jacobian, elementwise_grad or holomorphic_grad."
#     342         )
#
# File ~/thesis/.venv/lib/python3.12/site-packages/autograd/core.py:12, in make_vjp(fun, x)
#      10 def make_vjp(fun, x):
#      11     start_node = VJPNode.new_root()
# ---> 12     end_value, end_node = trace(start_node, fun, x)
#      13     if end_node is None:
#      15         def vjp(g):
#
# File ~/thesis/.venv/lib/python3.12/site-packages/autograd/tracer.py:12, in trace(start_node, fun, x)
#      10 with trace_stack.new_trace() as t:
#      11     start_box = new_box(x, t, start_node)
# ---> 12     end_box = fun(start_box)
#      13     if isbox(end_box) and end_box._trace == start_box._trace:
#      14         return end_box._value, end_box._node
#
# File ~/thesis/.venv/lib/python3.12/site-packages/autograd/wrap_util.py:17, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      15 else:
#      16     subargs = subvals(args, zip(argnum, x))
# ---> 17 return fun(*subargs, **kwargs)
#
# File ~/thesis/code/model.py:337, in Model.update_step.<locals>.<lambda>(p)
#     335 def update_step(self, input, output, step, callback, last_time):
#     336 	params, loss = self.optimizer.step_and_cost(
# --> 337 		lambda p: self.loss(p, input, output), self.params
#     338 	)
#     340 	self.losses.append(loss)
#     342 	if callback == 'text':
#
# File ~/thesis/code/model.py:220, in Model.loss(self, params, input, output)
#     218 def loss(self, params, input, output):
#     219 	predictions = np.array(
# --> 220 		[self.model(self.circuit, single, params) for single in input]
#     221 	).flatten()
#     223 	loss = np.mean((output - predictions) ** 2)
#     225 	return loss
#
# Cell In[4], line 59, in _model(circ, input, params)
#      58 def _model(circ, input, params):
# ---> 59 	return (circ(input, params) )
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/qnode.py:922, in QNode.__call__(self, *args, **kwargs)
#     919     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     921     return capture_qnode(self, *args, **kwargs)
# --> 922 return self._impl_call(*args, **kwargs)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/qnode.py:895, in QNode._impl_call(self, *args, **kwargs)
#     892 # Calculate the classical jacobians if necessary
#     893 self._transform_program.set_classical_component(self, args, kwargs)
# --> 895 res = execute(
#     896     (tape,),
#     897     device=self.device,
#     898     diff_method=self.diff_method,
#     899     interface=self.interface,
#     900     transform_program=self._transform_program,
#     901     gradient_kwargs=self.gradient_kwargs,
#     902     **self.execute_kwargs,
#     903 )
#     904 res = res[0]
#     906 # convert result to the interface in case the qfunc has no parameters
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/execution.py:233, in execute(tapes, device, diff_method, interface, grad_on_execution, cache, cachesize, max_diff, device_vjp, postselect_mode, mcm_method, gradient_kwargs, transform_program, executor_backend)
#     229 tapes, outer_post_processing = outer_transform(tapes)
#     231 assert not outer_transform.is_informative, "should only contain device preprocessing"
# --> 233 results = run(tapes, device, config, inner_transform)
#     234 return user_post_processing(outer_post_processing(results))
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/run.py:338, in run(tapes, device, config, inner_transform_program)
#     335         params = tape.get_parameters(trainable_only=False)
#     336         tape.trainable_params = qml.math.get_trainable_indices(params)
# --> 338 results = ml_execute(tapes, execute_fn, jpc, device=device)
#     339 return results
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/interfaces/autograd.py:147, in autograd_execute(tapes, execute_fn, jpc, device)
#     142 # TODO: Remove when PL supports pylint==3.3.6 (it is considered a useless-suppression) [sc-91362]
#     143 # pylint: disable=no-member
#     144 parameters = autograd.builtins.tuple(
#     145     [autograd.builtins.list(t.get_parameters()) for t in tapes]
#     146 )
# --> 147 return _execute(parameters, tuple(tapes), execute_fn, jpc)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/autograd/tracer.py:50, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      48 parents = tuple(box._node for _, box in boxed_args)
#      49 argnums = tuple(argnum for argnum, _ in boxed_args)
# ---> 50 ans = f_wrapped(*argvals, **kwargs)
#      51 node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      52 return new_box(ans, trace, node)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/autograd/tracer.py:54, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      52     return new_box(ans, trace, node)
#      53 else:
# ---> 54     return f_raw(*args, **kwargs)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/interfaces/autograd.py:184, in _execute(parameters, tapes, execute_fn, jpc)
#     166 @autograd.extend.primitive
#     167 def _execute(
#     168     parameters,
#    (...)    171     jpc,
#     172 ):
#     173     """Autodifferentiable wrapper around a way of executing tapes.
#     174
#     175     Args:
#    (...)    182
#     183     """
# --> 184     return _to_autograd(execute_fn(tapes))
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/jacobian_products.py:487, in DeviceDerivatives.execute_and_cache_jacobian(self, tapes)
#     485 if logger.isEnabledFor(logging.DEBUG):  # pragma: no cover
#     486     logger.debug("Forward pass called with %s", tapes)
# --> 487 results, jac = self._dev_execute_and_compute_derivatives(tapes)
#     488 self._results_cache[tapes] = results
#     489 self._jacs_cache[tapes] = jac
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/workflow/jacobian_products.py:452, in DeviceDerivatives._dev_execute_and_compute_derivatives(self, tapes)
#     446 """
#     447 Converts tapes to numpy before computing the the results and derivatives on the device.
#     448
#     449 Dispatches between the two different device interfaces.
#     450 """
#     451 numpy_tapes, _ = qml.transforms.convert_to_numpy_parameters(tapes)
# --> 452 return self._device.execute_and_compute_derivatives(numpy_tapes, self._execution_config)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/devices/modifiers/simulator_tracking.py:95, in _track_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      89     self.tracker.update(
#      90         execute_and_derivative_batches=1,
#      91         executions=len(batch),
#      92         derivatives=len(batch),
#      93     )
#      94     self.tracker.record()
# ---> 95 return untracked_execute_and_compute_derivatives(self, circuits, execution_config)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/devices/modifiers/single_tape_support.py:60, in _make_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      58     is_single_circuit = True
#      59     circuits = (circuits,)
# ---> 60 results, jacs = batch_execute_and_compute_derivatives(self, circuits, execution_config)
#      61 return (results[0], jacs[0]) if is_single_circuit else (results, jacs)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/devices/modifiers/simulator_tracking.py:95, in _track_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      89     self.tracker.update(
#      90         execute_and_derivative_batches=1,
#      91         executions=len(batch),
#      92         derivatives=len(batch),
#      93     )
#      94     self.tracker.record()
# ---> 95 return untracked_execute_and_compute_derivatives(self, circuits, execution_config)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane/devices/modifiers/single_tape_support.py:60, in _make_execute_and_compute_derivatives.<locals>.execute_and_compute_derivatives(self, circuits, execution_config)
#      58     is_single_circuit = True
#      59     circuits = (circuits,)
# ---> 60 results, jacs = batch_execute_and_compute_derivatives(self, circuits, execution_config)
#      61 return (results[0], jacs[0]) if is_single_circuit else (results, jacs)
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane_lightning/lightning_base/lightning_base.py:451, in LightningBase.execute_and_compute_derivatives(self, circuits, execution_config)
#     441 """Compute the results and jacobians of circuits at the same time.
#     442
#     443 Args:
#    (...)    448     Tuple: A numeric result of the computation and the gradient.
#     449 """
#     450 batch_obs = execution_config.device_options.get("batch_obs", self._batch_obs)
# --> 451 results = tuple(
#     452     self.simulate_and_jacobian(
#     453         self.dynamic_wires_from_circuit(circuit),
#     454         self._statevector,
#     455         batch_obs=batch_obs,
#     456         wire_map=self._wire_map,
#     457     )
#     458     for circuit in circuits
#     459 )
#     460 return tuple(zip(*results))
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane_lightning/lightning_base/lightning_base.py:452, in <genexpr>(.0)
#     441 """Compute the results and jacobians of circuits at the same time.
#     442
#     443 Args:
#    (...)    448     Tuple: A numeric result of the computation and the gradient.
#     449 """
#     450 batch_obs = execution_config.device_options.get("batch_obs", self._batch_obs)
#     451 results = tuple(
# --> 452     self.simulate_and_jacobian(
#     453         self.dynamic_wires_from_circuit(circuit),
#     454         self._statevector,
#     455         batch_obs=batch_obs,
#     456         wire_map=self._wire_map,
#     457     )
#     458     for circuit in circuits
#     459 )
#     460 return tuple(zip(*results))
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane_lightning/lightning_base/lightning_base.py:342, in LightningBase.simulate_and_jacobian(self, circuit, state, batch_obs, wire_map)
#     340 res = self.simulate(circuit, state)
#     341 # pylint: disable=not-callable
# --> 342 jac = self.LightningAdjointJacobian(state, batch_obs=batch_obs).calculate_jacobian(circuit)
#     343 return res, jac
#
# File ~/thesis/.venv/lib/python3.12/site-packages/pennylane_lightning/lightning_qubit/_adjoint_jacobian.py:100, in LightningAdjointJacobian.calculate_jacobian(self, tape)
#      96     return np.array([], dtype=self.dtype)
#      98 trainable_params = processed_data["tp_shift"]
# --> 100 jac = self._jacobian_lightning(
#     101     processed_data["state_vector"],
#     102     processed_data["obs_serialized"],
#     103     processed_data["ops_serialized"],
#     104     trainable_params,
#     105 )
#     107 jac = np.array(jac)
#     108 has_shape0: bool = len(jac) > 0
#
# KeyboardInterrupt:

# %%
print('Test score:', model.test())
# Out:
# Test score: 5.706214025673842e-07

# %%
model.draw_train()

# %%
model.draw()

# %%
model.serialize('models/' + model.name + '.json')
